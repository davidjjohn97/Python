# %%
# AIM: To find attributes that impact the Gross Revenue of movies
# by Analyzing Movies from last 4 decades


# Importing required Libraries
import pandas as pd
import seaborn as sbn
import os
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (15,5)

# Ensuring correct Directory
cwd = os.getcwd()
print("Current Working Directory",cwd)

# Read movies Data
df = pd.read_csv('movies.csv')

# Sneak-Peak on the Data(Head)
df.head()
# Out:
# Current Working Directory /Users/davidjjohn97/Portfolio_Pros
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
# ...

# %%
# Sneak-Peak on the Data(Tail)
df.tail()
# Out:
#                       name     rating      genre  year  \
# 7648     Bad Boys for Life          R     Action  2020
# 7649    Sonic the Hedgehog         PG     Action  2020
# 7650              Dolittle         PG  Adventure  2020
# 7651  The Call of the Wild         PG  Adventure  2020
# 7652     The Eight Hundred  Not Rated     Action  2020
#
#                                released  score     votes        director  \
# 7648   January 17, 2020 (United States)    6.6  140000.0    Adil El Arbi
# 7649  February 14, 2020 (United States)    6.5  102000.0     Jeff Fowler
# 7650   January 17, 2020 (United States)    5.6   53000.0  Stephen Gaghan
# 7651  February 21, 2020 (United States)    6.8   42000.0   Chris Sanders
# 7652    August 28, 2020 (United States)    6.8    3700.0         Hu Guan
#
#               writer               star        country       budget  \
# 7648     Peter Craig         Will Smith  United States   90000000.0
# ...

# %%
# Multiple NaN values where noticed
df = df.dropna()
# Resetting the index values 
df.reset_index(drop=True)
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 5416                               Bad Boys for Life          R     Action
# 5417                              Sonic the Hedgehog         PG     Action
# 5418                                        Dolittle         PG  Adventure
# 5419                            The Call of the Wild         PG  Adventure
# 5420                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score      votes  \
# ...

# %%
# Check for missing data

for col in df.columns:
    percent_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col,percent_missing))
# Out:
# name - 0.0%
# rating - 0.0%
# genre - 0.0%
# year - 0.0%
# released - 0.0%
# score - 0.0%
# votes - 0.0%
# director - 0.0%
# writer - 0.0%
# star - 0.0%
# country - 0.0%
# budget - 0.0%
# gross - 0.0%
# company - 0.0%
# runtime - 0.0%

# %%
# NaN Values where cleaned successfully
# Looking up Column datatypes
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# Converting columns votes TO Integer type
df['votes']= df['votes'].astype('int64')
df['budget']= df['budget'].astype('int64')
df['gross']= df['gross'].astype('int64')

# Updating released column to correct year format
for s in df['released']:
    start = s.find(",") + 1
    end = s.find("(")
    df['year']= s[start:end]
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#         year                           released  score    votes  \
# ...

# %%
# Ordering movies by gross revenue
df.sort_values(by=['gross'], inplace=False, ascending=False)

## Listing entire data
# pd.set_option('display.max_rows',None)
# Out:
#                                             name     rating   genre    year  \
# 5445                                      Avatar      PG-13  Action   2020
# 7445                           Avengers: Endgame      PG-13  Action   2020
# 3045                                     Titanic      PG-13   Drama   2020
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action   2020
# 7244                      Avengers: Infinity War      PG-13  Action   2020
# ...                                          ...        ...     ...     ...
# 5640                                 Tanner Hall          R   Drama   2020
# 2434                  Philadelphia Experiment II      PG-13  Action   2020
# 3681                                Ginger Snaps  Not Rated   Drama   2020
# 272                                     Parasite          R  Horror   2020
# 3203                                  Trojan War      PG-13  Comedy   2020
#
# ...

# %%
# Using Drop Duplicates to list UNIQUE Companies
df['company'].drop_duplicates().sort_values(ascending=False)
# Out:
# 7129                                thefyzz
# 5664                            micro_scope
# 4007                               i5 Films
# 6793                             i am OTHER
# 6420                                   erbp
#                        ...
# 385                        1818 Productions
# 2929                          1492 Pictures
# 3024                        .406 Production
# 7525    "Weathering With You" Film Partners
# 4345        "DIA" Productions GmbH & Co. KG
# Name: company, Length: 1475, dtype: object

# %%
# Creating Scatterplot to compare Budget and Gross 
plt.scatter(x=df['budget'], y=df['gross'])
plt.title('Budget Vs Gross Earnings')
plt.xlabel('Film Budget')
plt.ylabel('Gross Earnings')
plt.show()

# %%
# Regression plot to check correlation between Budget and Gross
sbn.regplot(x='budget',y='gross',data = df, scatter_kws={"color":"red"},line_kws={"color":"darkblue"})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
# Positive correlation was noted in the plot
# Listing numerical correlation
df.corr()
# Out:
#             score     votes    budget     gross   runtime
# score    1.000000  0.474256  0.072001  0.222556  0.414068
# votes    0.474256  1.000000  0.439675  0.614751  0.352303
# budget   0.072001  0.439675  1.000000  0.740247  0.318695
# gross    0.222556  0.614751  0.740247  1.000000  0.275796
# runtime  0.414068  0.352303  0.318695  0.275796  1.000000

# %%
# High Correlation verified between Budget and Gross Earnings

# %%
correlation_matrix = df.corr()
sbn.heatmap(correlation_matrix,annot=True)
plt.title('Correlation Matrix')
plt.xlabel('Movie Attributes')
plt.ylabel('Movie Attributes')
plt.show()

# %%
# To validate the correlation of Company and Gross Earnings the
# charachter variable Company is converted to unique numeric values

df_Numerized = df

for col_n in df_Numerized.columns:
    if(df_Numerized[col_n].dtype == 'object'):
        df_Numerized[col_n] = df_Numerized[col_n].astype('category')
        df_Numerized[col_n] = df_Numerized[col_n].cat.codes
        
df_Numerized
# Out:
#       name  rating  genre  year  released  score    votes  director  writer  \
# 0     4692       6      6     0      1304    8.4   927000      1795    2832
# 1     3929       6      1     0      1127    5.8    65000      1578    1158
# 2     3641       4      0     0      1359    8.7  1200000       757    1818
# 3      204       4      4     0      1127    7.7   221000       889    1413
# 4      732       6      4     0      1170    7.3   108000       719     351
# ...    ...     ...    ...   ...       ...    ...      ...       ...     ...
# 7648   415       6      0     0       904    6.6   140000        16    2390
# 7649  3556       4      0     0       713    6.5   102000       852    2309
# 7650  1153       4      1     0       904    5.6    53000      1809    2827
# 7651  3978       4      1     0       758    6.8    42000       294    2091
# 7652  4090       3      0     0       370    6.8     3700       746    1184
#
# ...

# %%
correlation_matrix = df_Numerized.corr()
sbn.heatmap(correlation_matrix,annot=True)
plt.title('Correlation Matrix of Numerized Variables')
plt.xlabel('Movie Attributes')
plt.ylabel('Movie Attributes')
plt.show()

# %%
correlation_matrix = df_Numerized.corr()
corr_pairs = correlation_matrix.unstack().sort_values()
corr_pairs
high_corr = corr_pairs[corr_pairs > 0.5]
high_corr
# Out:
# votes     gross       0.614751
# gross     votes       0.614751
#           budget      0.740247
# budget    gross       0.740247
# name      name        1.000000
# gross     gross       1.000000
# budget    budget      1.000000
# country   country     1.000000
# star      star        1.000000
# writer    writer      1.000000
# director  director    1.000000
# votes     votes       1.000000
# score     score       1.000000
# released  released    1.000000
# genre     genre       1.000000
# rating    rating      1.000000
# company   company     1.000000
# runtime   runtime     1.000000
# dtype: float64
